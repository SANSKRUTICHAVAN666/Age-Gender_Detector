# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# #plotting

# %%
img1=cv2.imread(r"C:\Users\Sanskruti\OneDrive\Documents\agegenderdetector\puppy.png",0)

# %%
plt.imshow(img)

# %% [markdown]
# #Arithmetic operationd

# %%
img2=cv2.imread(r"C:\Users\Sanskruti\OneDrive\Documents\agegenderdetector\pink.jpeg",0)

# %%
img1_resize=cv2.resize(img2,(100,100))

# %%
img2_resize=cv2.resize(img1,(100,100))

# %% [markdown]
# #Addition

# %%
result=img1_resize+img2_resize

# %%
plt.imshow(result)

# %% [markdown]
# #subtraction

# %%
result=img1_resize-img2_resize

# %%
plt.imshow(result)

# %% [markdown]
# #multiplication

# %%
result=img1_resize*img2_resize
plt.imshow(result)

# %% [markdown]
# #division

# %%
result=img1_resize/img2_resize
plt.imshow(result)

# %% [markdown]
# #blur

# %%
img1=cv2.imread(r"C:\Users\Sanskruti\OneDrive\Documents\agegenderdetector\puppy.png")
img=cv2.cvtColor(img1,cv2.COLOR_BGR2HSV)
figure_size=10
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("Original")
plt.xticks([]),plt.yticks([])
plt.subplot(131),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2RGB)),plt.title("Blurred")
plt.xticks([]),plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #zoom

# %%
img1=cv2.imread(r"C:\Users\Sanskruti\OneDrive\Documents\agegenderdetector\puppy.png")

# %%
(height,width)=img1.shape[0:2]
zoom=cv2.resize(img1,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom=cv2.resize(img1,(int(width*2),int(height*2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %% [markdown]
# #rotate

# %%
m=cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate=cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %% [markdown]
# translation

# %%
import numpy as np

# %%
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img1,m,(height,width))
plt.imshow(dst)
